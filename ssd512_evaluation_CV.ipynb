# %% [markdown]
# # SSD512 Evaluation
#
# We'll evaluate an SSD512 on the Computer Vision and Deep Learning `test` dataset, but note that the `Evaluator` works for any SSD model and any dataset that is compatible with the `DataGenerator`. If you would like to run the evaluation on a different model and/or dataset, the procedure is analogous to what is shown below, you just have to build the appropriate model and load the relevant dataset.
#
# Note: In case you want to evaluate any of the provided trained models, make sure that you build the respective model with the correct set of scaling factors to reproduce the official results.

# %%
# Downgrade tensoflow
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# Downgrade gast version 0.2.2
# !pip install gast==0.2.2
# Out:
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=202fbc45cdfca2bd006ba1064b71aec1634b0e83a083f7125d17d05fda67e0c2
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# Installing collected packages: gast
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# Successfully installed gast-0.2.2

# %%
# Downgrade keras version 2.2.4
# !pip install keras==2.2.4
# Out:
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 2.8MB/s
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Installing collected packages: keras
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.2.4

# %%
# Upload the gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Unzip the dataset
# !unzip '/content/drive/My Drive/Dataset_CV.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Dataset_CV/ImagesDir/2_329_193_084331-916916.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_193_084332-243243.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_193_084332-702702.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_193_084334-169169.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_193_084334-841841.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_193_084335-192192.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_193_084335-481481.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_193_084336-269269.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1958_071322-181181.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1958_071323-687687.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1958_071325-228228.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_084337-393393.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_095132-579579.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_095134-02020.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_103907-522522.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_103909-03131.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_103910-574574.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_103912-08080.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_103913-624624.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_103915-131131.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_103916-671671.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_195_103918-181181.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1966_071344-835835.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1969_071345-676676.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084343-840840.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084344-313313.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084344-587587.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084344-879879.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084345-754754.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084346-110110.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084346-653653.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084346-919919.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084347-187187.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084348-347347.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084348-816816.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084349-104104.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_196_084349-187187.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084343-688688.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084346-393393.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084349-397397.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084349-648648.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084351-07575.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084351-327327.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084351-959959.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084352-310310.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084352-597597.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084352-880880.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084353-144144.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084353-338338.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084353-409409.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084353-698698.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084353-788788.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084354-05757.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084354-326326.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084354-586586.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084354-828828.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084355-09090.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084355-350350.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084355-608608.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084355-655655.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084356-118118.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084356-378378.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084357-554554.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084358-06060.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084358-344344.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084358-380380.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084358-632632.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084358-891891.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084400-816816.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084400-819819.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_197_084401-283283.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_084349-671671.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_084349-916916.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_084349-942942.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_084350-219219.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_084350-524524.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_084350-791791.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_103936-715715.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_103938-155155.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_103939-497497.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_103940-936936.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_103942-309309.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_103943-752752.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_103945-159159.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_199_103946-740740.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_071533-246246.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072414-902902.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072416-445445.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072417-958958.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072419-495495.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072421-0033.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072422-544544.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072424-05353.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072425-563563.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072427-06969.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_19_072428-611611.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1_052709-592592.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1_052709-925925.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1_052710-590590.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1_052710-932932.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1_070007-245245.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1_070008-756756.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_1_070010-294294.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_2000_071722-610610.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_201_084431-06464.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_201_084431-715715.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_201_084432-197197.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_201_084432-530530.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_201_095729-587587.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_201_103949-451451.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_2037_072020-845845.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_2037_072022-315315.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084405-316316.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084407-264264.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084407-525525.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084407-723723.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084407-989989.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084408-423423.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084408-784784.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084410-290290.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084410-898898.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084411-301301.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084411-651651.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084412-301301.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084412-672672.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084413-630630.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084414-128128.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084414-493493.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084414-860860.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084416-256256.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084416-733733.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084416-990990.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084417-889889.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_084418-513513.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_100408-787787.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_100410-160160.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_100411-568568.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_203_104536-397397.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_204_084419-944944.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_204_084420-466466.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_204_084420-725725.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_204_084421-0022.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_204_084421-279279.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_204_084421-590590.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_204_084421-831831.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_205_084421-966966.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_205_084422-08282.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_205_084422-352352.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_205_084422-413413.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_205_084422-620620.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_205_
jpg
#   inflating: Dataset_CV/ImagesDir/2_329_507_114448-361361.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_507_133204-993993.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114449-101101.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114449-600600.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114450-09292.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114450-641641.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114451-160160.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114451-700700.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114452-280280.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114452-760760.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114453-350350.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114453-881881.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114454-451451.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114455-03131.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114455-521521.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114456-05050.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114456-631631.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114457-141141.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114457-730730.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114458-220220.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114458-737737.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114459-371371.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114459-851851.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114500-341341.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114500-840840.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114501-201201.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_114501-540540.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_508_133319-962962.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133247-930930.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133248-266266.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133248-935935.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133303-584584.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133308-342342.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133320-532532.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133321-07474.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133321-672672.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133322-192192.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133323-232232.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133323-672672.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133324-138138.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133324-612612.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_509_133325-143143.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_50_073619-709709.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_50_073620-04444.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_50_073620-686686.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_50_073621-04343.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_510_114501-751751.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_510_114502-05050.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_510_114502-261261.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_510_133246-390390.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_510_133246-723723.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_510_133247-05959.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_510_133247-452452.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_510_135247-124124.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_511_133301-737737.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_511_133304-219219.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_511_133304-958958.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_511_133318-664664.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_511_133318-999999.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_511_133319-652652.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_511_133320-252252.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_511_133320-742742.jpg
#   inflating: Dataset_CV/ImagesDir/2_329_511_133321-322322.jpg

# %%
# Enter in ssd_keras dir
# %cd /content/drive/My Drive/ssd_keras-master/Group-1-PersonDetectionFromTopView
# Out:
# /content/drive/My Drive/ssd_keras-master

# %%
from keras import backend as K
from keras.models import load_model
from keras.optimizers import Adam
from skimage.io import imread
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd512 import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization
from data_generator.object_detection_2d_data_generator import DataGenerator
from eval_utils.average_precision_evaluator import Evaluator

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Set a few configuration parameters.
img_height = 512
img_width = 512
n_classes = 1
model_mode = 'inference'

# %% [markdown]
# ## 1. Load a trained SSD
#
# Either load a trained model or build a model and load trained weights into it. You can then of course save the model and next time load the full model directly, without having to build it.

# %% [markdown]
# ### 1.1. Build the model and load trained weights into it

# %%
# 1: Build the Keras model

K.clear_session() # Clear previous models from memory.

model = ssd_512(image_size=(img_height, img_width, 3),
                n_classes=n_classes,
                mode=model_mode,
                l2_regularization=0.0005,
                scales=[0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05], # The scales for MS COCO [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05]
                aspect_ratios_per_layer=[[1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0], 
                                         [1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5]],
                two_boxes_for_ar1=True,
                steps=[8, 16, 32, 64, 128, 256, 512],
                offsets=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
                clip_boxes=False,
                variances=[0.1, 0.1, 0.2, 0.2],
                normalize_coords=True,
                subtract_mean=[123, 117, 104],
                swap_channels=[2, 1, 0],
                confidence_thresh=0.01,
                iou_threshold=0.45,
                top_k=200,
                nms_max_output_size=400)

# 2: Load the trained weights into the model.

# Set the path of the trained weights.
weights_path = '/content/drive/My Drive/ssd_keras_model/ssd512_cvdata_epoch-25_loss-2.0090_val_loss-1.5760.h5'

model.load_weights(weights_path, by_name=True)

# 3: Compile the model so that Keras won't complain the next time you load it.

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/ssd_keras-master/keras_layers/keras_layer_DecodeDetections.py:174: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/ssd_keras-master/keras_loss_function/keras_ssd_loss.py:95: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/ssd_keras-master/keras_loss_function/keras_ssd_loss.py:166: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %% [markdown]
# Or

# %% [markdown]
# ### 1.2. Load a trained model
#
# We set `model_mode` to 'inference' above, so the evaluator expects that you load a model that was built in 'inference' mode. If you're loading a model that was built in 'training' mode, change the `model_mode` parameter accordingly.

# %%
# Set the path to the `.h5` file of the model to be loaded.
model_path = '/content/drive/My Drive/ssd_keras_model/ssd512_cvdata_epoch-18_loss-2.1282_val_loss-1.6612.h5'

# We need to create an SSDLoss object in order to pass that to the model loader.
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

K.clear_session() # Clear previous models from memory.

model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                               'L2Normalization': L2Normalization,
                                               'DecodeDetections': DecodeDetections,
                                               'compute_loss': ssd_loss.compute_loss})

# %% [markdown]
# ## 2. Create a data generator for the evaluation dataset
#
# Instantiate a `DataGenerator` that will serve the evaluation dataset during the prediction phase.

# %%
dataset = DataGenerator()

# Set the paths to the dataset here.
Dataset_CV_images_dir       = '/content/Dataset_CV/ImagesDir/'
Dataset_CV_annotations_dir  = '/content/Dataset_CV/AnnotationsDir/'
Dataset_CV_test_image_set_filename     = '/content/Dataset_CV/ImageSet/test.txt'

# The XML parser needs to now what object class names to look for and in which order to map them to integers.
classes = ['background', 'person']

dataset.parse_xml(images_dirs=[Dataset_CV_images_dir],
                      image_set_filenames=[Dataset_CV_test_image_set_filename],
                      annotations_dirs=[Dataset_CV_annotations_dir],
                      classes=classes,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=False,
                      ret=False)
# Out:
# Processing image set 'test.txt': 100%|██████████| 5082/5082 [00:08<00:00, 581.11it/s]

# %% [markdown]
# ## 3. Run the evaluation
#
# Now that we have instantiated a model and a data generator to serve the dataset, we can set up the evaluator and run the evaluation.
#
# The evaluator is quite flexible: It can compute the average precisions according to the Pascal VOC pre-2010 algorithm, which samples 11 equidistant points of the precision-recall curves, or according to the Pascal VOC post-2010 algorithm, which integrates numerically over the entire precision-recall curves instead of sampling a few individual points. You could also change the number of sampled recall points or the required IoU overlap for a prediction to be considered a true positive, among other things. Check out the `Evaluator`'s documentation for details on all the arguments.
#
# In its default settings, the evaluator's algorithm is identical to the official Pascal VOC pre-2010 Matlab detection evaluation algorithm, so you don't really need to tweak anything unless you want to.
#
# The evaluator roughly performs the following steps: It runs predictions over the entire given dataset, then it matches these predictions to the ground truth boxes, then it computes the precision-recall curves for each class, then it samples 11 equidistant points from these precision-recall curves to compute the average precision for each class, and finally it computes the mean average precision over all classes.

# %%
evaluator = Evaluator(model=model,
                      n_classes=n_classes,
                      data_generator=dataset,
                      model_mode=model_mode)

results = evaluator(img_height=img_height,
                    img_width=img_width,
                    batch_size=8,
                    data_generator_mode='resize',
                    round_confidences=False,
                    matching_iou_threshold=0.5,
                    border_pixels='include',
                    sorting_algorithm='quicksort',
                    average_precision_mode='sample',
                    num_recall_points=11,
                    ignore_neutral_boxes=True,
                    return_precisions=True,
                    return_recalls=True,
                    return_average_precisions=True,
                    return_average_matches=True,
                    verbose=True)

mean_average_precision, average_matches, average_precisions, precisions, recalls = results
# Out:
# Number of images in the evaluation dataset: 5082
#
# Producing predictions batch-wise: 100%|██████████| 636/636 [04:12<00:00,  2.51it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 79838/79838 [00:05<00:00, 14638.81it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# Computing average IOU, class 1/1

# %% [markdown]
# ## 4. Visualize the results
#
# Let's take a look:

# %%
for i in range(1, len(average_matches)):
    print("{:<14}{:<6}{}".format(classes[i], 'IOU', round(average_matches[i], 3)))
print()

for i in range(1, len(average_precisions)):
    print("{:<14}{:<6}{}".format(classes[i], 'AP', round(average_precisions[i], 3)))
print()
#print("{:<14}{:<6}{}".format('','mAP', round(mean_average_precision, 3)))
# Out:
# person        IOU   0.941
#
# person        AP    0.907

# %%
m = max((n_classes + 1) // 2, 2)
n = 2

fig, cells = plt.subplots(m, n, figsize=(n*8,m*8))
for i in range(m):
    for j in range(n):
        if n*i+j+1 > n_classes: break
        cells[i, j].plot(recalls[n*i+j+1], precisions[n*i+j+1], color='blue', linewidth=1.0)
        cells[i, j].set_xlabel('recall', fontsize=14)
        cells[i, j].set_ylabel('precision', fontsize=14)
        cells[i, j].grid(True)
        cells[i, j].set_xticks(np.linspace(0,1,11))
        cells[i, j].set_yticks(np.linspace(0,1,11))
        cells[i, j].set_title("{}, AP: {:.3f}".format(classes[n*i+j+1], average_precisions[n*i+j+1]), fontsize=16)

# %% [markdown]
# ## 5. Advanced use
#
# `Evaluator` objects maintain copies of all relevant intermediate results like predictions, precisions and recalls, etc., so in case you want to experiment with different parameters, e.g. different IoU overlaps, there is no need to compute the predictions all over again every time you make a change to a parameter. Instead, you can only update the computation from the point that is affected onwards.
#
# The evaluator's `__call__()` method is just a convenience wrapper that executes its other methods in the correct order. You could just call any of these other methods individually as shown below (but you have to make sure to call them in the correct order).
#
# Note that the example below uses the same evaluator object as above. Say you wanted to compute the Pascal VOC post-2010 'integrate' version of the average precisions instead of the pre-2010 version computed above. The evaluator object still has an internal copy of all the predictions, and since computing the predictions makes up the vast majority of the overall computation time and since the predictions aren't affected by changing the average precision computation mode, we skip computing the predictions again and instead only compute the steps that come after the prediction phase of the evaluation. We could even skip the matching part, since it isn't affected by changing the average precision mode either. In fact, we would only have to call `compute_average_precisions()` `compute_mean_average_precision()` again, but for the sake of illustration we'll re-do the other computations, too.

# %%
evaluator.get_num_gt_per_class(ignore_neutral_boxes=True,
                               verbose=False,
                               ret=False)

evaluator.match_predictions(ignore_neutral_boxes=True,
                            matching_iou_threshold=0.5,
                            border_pixels='include',
                            sorting_algorithm='quicksort',
                            verbose=True,
                            ret=False)

precisions, recalls = evaluator.compute_precision_recall(verbose=True, ret=True)

average_precisions = evaluator.compute_average_precisions(mode='integrate',
                                                          num_recall_points=11,
                                                          verbose=True,
                                                          ret=True)

mean_average_precision = evaluator.compute_mean_average_precision(ret=True)
# Out:
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 403661/403661 [00:41<00:00, 9775.27it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1

# %%
for i in range(1, len(average_precisions)):
    print("{:<14}{:<6}{}".format(classes[i], 'AP', round(average_precisions[i], 3)))
print()
print("{:<14}{:<6}{}".format('','mAP', round(mean_average_precision, 3)))
# Out:
# person        AP    0.768
#
#               mAP   0.768
